# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
himn = """Cesó la horrible noche,

La libertad sublime

Derrama las auroras

De su invencible luz.

La humanidad entera,

Que entre cadenas gime,

Comprende las palabras

Del que murió en la cruz."""

print(himn)
# Out:
# Cesó la horrible noche,
#
# La libertad sublime
#
# Derrama las auroras
#
# De su invencible luz.
#
# La humanidad entera,
#
# Que entre cadenas gime,
#
# Comprende las palabras
#
# Del que murió en la cruz.

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
list1 = [himn[0:5]]
list1.append("Wolrd")
print(list1)
# Out:
# ['Cesó ', 'Wolrd']
